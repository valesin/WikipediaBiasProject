# %%
import pandas as pd
d = pd.read_csv("../data/out/SpotlightWeightSource_0102_0505_fullmatch.csv")

# %%
d['fullmatch_count'].value_counts()
# Out:
# fullmatch_count
# 0      9413064
# 1      2335656
# 2       405012
# 3       131223
# 4        58472
#         ...
# 302          1
# 321          1
# 403          1
# 260          1
# 367          1
# Name: count, Length: 318, dtype: int64
