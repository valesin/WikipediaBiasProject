# %% [markdown]
# # Wikipedia Bias Analysis: Pageview-Filtered Networks
#
# This notebook analyzes retention bias in Wikipedia link networks filtered by page popularity (pageviews).
#
# ## Filtering Modes
#
# 1. **Language-Specific**: Different pageview thresholds per language edition
# 2. **Global/Multilayer**: Single threshold based on aggregated pageviews across all languages
#
# ## Workflow
#
# 1. **Exploration**: Compare statistics for multiple quantile thresholds
# 2. **Analysis**: Select one threshold and run complete bias analysis
# 3. **Results**: View and save retention curves and AUC matrices
#
# ## Dataset
#
# - **Edges**: Weighted links from DBpedia Spotlight
# - **Metadata**: Demographic attributes (gender, birth year, region)
# - **Pageviews**: Daily average views from Wikipedia API

# %% [markdown]
# ## Setup and Imports

# %%
import os
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import logging

# Add project root to Python path
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

print(f"Project root: {project_root}")

# Configure logging
logging.basicConfig(
    level=logging.INFO,
    format='%(levelname)s: %(message)s'
)

# Import analysis modules
from src import analysis, filters

# Force reload to get latest code changes
import importlib
importlib.reload(analysis)
importlib.reload(filters)

print("✓ Modules imported and reloaded successfully")

# Set visualization defaults
plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette('husl')
# %matplotlib inline

# Helper function
def extract_dataset_name(csv_path):
    """Extract dataset name from CSV filename (without extension)."""
    basename = os.path.basename(csv_path)
    return os.path.splitext(basename)[0]

print("✓ Setup complete")
# Out:
# Project root: /home/vlr/Workspaces/WikipediaBiasProject/PyProject
# ✓ Modules imported and reloaded successfully
# ✓ Setup complete

# %% [markdown]
# ## Configuration
#
# **Modify these variables** to change the analysis parameters.

# %%
# ============================================================================
# DATA PATHS
# ============================================================================

# Edges CSV (update to your most recent SpotlightWeightSource file)
EDGE_CSV = os.path.join(project_root, "data/out/SpotlightWeightSource_0102_0505.csv")

# Metadata CSV
META_CSV = os.path.join(project_root, "data/entities_filtered_by_languages.csv")

# Pageviews CSV (generated by: python src/main.py pageviews)
PAGEVIEW_CSV = os.path.join(project_root, "data/out/pageviews_2023-01-01_to_2025-12-31.csv")

# Output directory
BASE_OUTPUT_DIR = os.path.join(project_root, "data/out/plots")
os.makedirs(BASE_OUTPUT_DIR, exist_ok=True)

# ============================================================================
# ANALYSIS PARAMETERS
# ============================================================================

# Languages to analyze
SELECTED_LANGUAGES = ['en', 'de', 'fr', 'it', 'es']

# Attributes to analyze
ATTRIBUTES = ['gender', 'un_subregion', 'bigperiod_birth']

# Statistical parameters
MIN_EDGES = 500  # Minimum edges for statistical reliability
RESOLUTION = 50  # Threshold points (higher = more precise but slower)
LOGSPACE_LOWER_BOUND = -14  # Lower bound for logspace threshold calculation

# ============================================================================
# FILTERING MODE
# ============================================================================

# False = Language-specific filtering (different threshold per language)
# True = Global/multilayer filtering (same node set across all languages)
USE_GLOBAL_PAGEVIEWS = False

# ============================================================================
# EXPLORATION: Thresholds to compare
# ============================================================================

# Quantile values to explore (0.8 = top 20%, 0.9 = top 10%, etc.)
EXPLORE_QUANTILES = [0.5, 0.7, 0.8, 0.9]

# ============================================================================
# ANALYSIS: Selected threshold (set after exploring)
# ============================================================================

# Quantile threshold for full analysis
ANALYSIS_QUANTILE = 0.8  # Change this after reviewing exploration results

# Alternative: Use absolute threshold instead of quantile
# ANALYSIS_ABSOLUTE = 1000  # Uncomment and modify analysis code to use this

# ============================================================================

DATASET_NAME = extract_dataset_name(EDGE_CSV)
print(f"Configuration loaded: {len(SELECTED_LANGUAGES)} languages, {len(ATTRIBUTES)} attributes")
print(f"Dataset: {DATASET_NAME}")
print(f"Filtering mode: {'Global/Multilayer' if USE_GLOBAL_PAGEVIEWS else 'Language-Specific'}")
# Out:
# Configuration loaded: 5 languages, 3 attributes
# Dataset: SpotlightWeightSource_0102_0505
# Filtering mode: Language-Specific

# %% [markdown]
# ## Load Data

# %%
print("Loading data...")
edges_df = pd.read_csv(EDGE_CSV)
meta_df = pd.read_csv(META_CSV)
pageviews_df = pd.read_csv(PAGEVIEW_CSV)

print(f"✓ Loaded {len(edges_df):,} edges")
print(f"✓ Loaded {len(meta_df):,} metadata records")
print(f"✓ Loaded {len(pageviews_df):,} pageview records")

print(f"\nEdge columns: {list(edges_df.columns)}")
print(f"Meta columns: {list(meta_df.columns)}")
print(f"Pageview columns: {list(pageviews_df.columns)}")

print(f"\nPageview statistics:")
print(f"  Min: {pageviews_df['pageviews'].min():.2f}")
print(f"  Median: {pageviews_df['pageviews'].median():.2f}")
print(f"  Mean: {pageviews_df['pageviews'].mean():.2f}")
print(f"  Max: {pageviews_df['pageviews'].max():.2f}")
# Out:
# Loading data...
# ✓ Loaded 12,444,180 edges
# ✓ Loaded 94,403 metadata records
# ✓ Loaded 471,638 pageview records
#
# Edge columns: ['language_code', 'source_wikidata_id', 'target_wikidata_id', 'weight']
# Meta columns: ['wikidata_id', 'birth', 'bigperiod_birth', 'un_subregion', 'gender']
# Pageview columns: ['wikidata_id', 'language_code', 'pageviews']
#
# Pageview statistics:
#   Min: 0.00
#   Median: 9.00
#   Mean: 123.06
#   Max: 145465.00

# %% [markdown]
# ---
# # Exploration: Compare Thresholds
#
# This section compares different quantile thresholds **without running the full analysis**.
#
# Review the statistics below, then:
# 1. Set `ANALYSIS_QUANTILE` in the configuration cell above
# 2. Rerun from the Analysis section

# %%
print("=" * 80)
print("EXPLORATION: Comparing Quantile Thresholds")
print("=" * 80)
print(f"Filtering mode: {'Global (multilayer)' if USE_GLOBAL_PAGEVIEWS else 'Language-specific'}\n")

# Aggregate pageviews if using global mode
if USE_GLOBAL_PAGEVIEWS:
    print("Aggregating pageviews across all languages...")
    pageviews_agg = pageviews_df.groupby('wikidata_id')['pageviews'].sum().reset_index()
    pageviews_agg.columns = ['wikidata_id', 'pageviews_total']
    print(f"✓ Aggregated pageviews for {len(pageviews_agg):,} unique entities\n")
    
    # Show aggregated pageview statistics
    print("Aggregated pageview statistics:")
    print(f"  Min: {pageviews_agg['pageviews_total'].min():.2f}")
    print(f"  Median: {pageviews_agg['pageviews_total'].median():.2f}")
    print(f"  Mean: {pageviews_agg['pageviews_total'].mean():.2f}")
    print(f"  Max: {pageviews_agg['pageviews_total'].max():.2f}")
    print()
else:
    pageviews_agg = pageviews_df

# Compare quantiles
results_summary = []

for quantile in EXPLORE_QUANTILES:
    print(f"\nQuantile {quantile:.2f} (top {(1-quantile)*100:.0f}%)")
    print("-" * 50)
    
    # Calculate threshold
    if USE_GLOBAL_PAGEVIEWS:
        threshold = pageviews_agg['pageviews_total'].quantile(quantile)
        pageviews_col = 'pageviews_total'
    else:
        threshold = pageviews_df['pageviews'].quantile(quantile)
        pageviews_col = 'pageviews'
    
    print(f"  Threshold value: {threshold:.2f} daily views")
    
    # Count retained entities
    if USE_GLOBAL_PAGEVIEWS:
        retained_entities = pageviews_agg[pageviews_agg[pageviews_col] >= threshold]['wikidata_id'].unique()
        total_entities = pageviews_agg['wikidata_id'].nunique()
    else:
        retained_entities = pageviews_df[pageviews_df[pageviews_col] >= threshold]['wikidata_id'].unique()
        total_entities = pageviews_df['wikidata_id'].nunique()
    
    n_retained = len(retained_entities)
    pct_retained = (n_retained / total_entities) * 100
    
    print(f"  Entities retained: {n_retained:,} / {total_entities:,} ({pct_retained:.1f}%)")
    
    # Calculate actual edge retention (both source AND target must be retained)
    retained_set = set(retained_entities)
    
    # Filter edges: keep only if both source and target are in retained set
    edges_retained = edges_df[
        edges_df['source_wikidata_id'].isin(retained_set) & 
        edges_df['target_wikidata_id'].isin(retained_set)
    ]
    
    n_edges_retained = len(edges_retained)
    edge_retention_rate = (n_edges_retained / len(edges_df)) * 100
    
    print(f"  Edges retained: {n_edges_retained:,} / {len(edges_df):,} ({edge_retention_rate:.1f}%)")
    
    results_summary.append({
        'quantile': quantile,
        'threshold': threshold,
        'entities_retained': n_retained,
        'entities_pct': pct_retained,
        'edges_retained': n_edges_retained,
        'edges_pct': edge_retention_rate
    })

# Summary table
print("\n" + "=" * 80)
print("SUMMARY TABLE")
print("=" * 80)
summary_df = pd.DataFrame(results_summary)
summary_df.columns = ['Quantile', 'Threshold', 'Entities', 'Entities %', 'Edges', 'Edges %']
print(summary_df.to_string(index=False))

print("\n" + "=" * 80)
print("Based on these statistics, set ANALYSIS_QUANTILE in the configuration cell above.")
print("Then rerun from the Analysis section below.")
print("=" * 80)
# Out:
# ================================================================================
# EXPLORATION: Comparing Quantile Thresholds
# ================================================================================
# Filtering mode: Language-specific
#
#
# Quantile 0.50 (top 50%)
# --------------------------------------------------
#   Threshold value: 9.00 daily views
#   Entities retained: 82,342 / 94,403 (87.2%)
#   Edges retained: 11,403,103 / 12,444,180 (91.6%)
#
# Quantile 0.70 (top 30%)
# --------------------------------------------------
#   Threshold value: 28.00 daily views
#   Entities retained: 63,024 / 94,403 (66.8%)
#   Edges retained: 9,138,355 / 12,444,180 (73.4%)
#
# Quantile 0.80 (top 20%)
# --------------------------------------------------
#   Threshold value: 60.00 daily views
#   Entities retained: 48,797 / 94,403 (51.7%)
#   Edges retained: 6,930,286 / 12,444,180 (55.7%)
#
# Quantile 0.90 (top 10%)
# --------------------------------------------------
#   Threshold value: 181.00 daily views
#   Entities retained: 30,118 / 94,403 (31.9%)
#   Edges retained: 4,121,366 / 12,444,180 (33.1%)
#
# ================================================================================
# SUMMARY TABLE
# ================================================================================
#  Quantile  Threshold  Entities  Entities %    Edges   Edges %
#       0.5        9.0     82342   87.223923 11403103 91.634025
#       0.7       28.0     63024   66.760590  9138355 73.434770
#       0.8       60.0     48797   51.690095  6930286 55.690982
#       0.9      181.0     30118   31.903647  4121366 33.118823
#
# ================================================================================
# Based on these statistics, set ANALYSIS_QUANTILE in the configuration cell above.
# Then rerun from the Analysis section below.
# ================================================================================

# %% [markdown]
# ---
# # Analysis: Run Bias Analysis with Selected Threshold
#
# This section runs the complete bias analysis with the selected quantile threshold.

# %%
print("=" * 80)
if USE_GLOBAL_PAGEVIEWS:
    print(f"ANALYSIS: Global pageview filtering (quantile={ANALYSIS_QUANTILE})")
    filter_desc = f"pageview_q{ANALYSIS_QUANTILE}_global"
else:
    print(f"ANALYSIS: Language-specific pageview filtering (quantile={ANALYSIS_QUANTILE})")
    filter_desc = f"pageview_q{ANALYSIS_QUANTILE}_lang"
print("=" * 80)

# Build filter function
if USE_GLOBAL_PAGEVIEWS:
    filter_func = filters.restrict_by_pageviews_quantile_global(pageviews_df, ANALYSIS_QUANTILE)
    print(f"✓ Created global pageview filter (top {(1-ANALYSIS_QUANTILE)*100:.0f}%)")
else:
    filter_func = filters.restrict_by_pageviews_quantile(pageviews_df, ANALYSIS_QUANTILE)
    print(f"✓ Created language-specific pageview filter (top {(1-ANALYSIS_QUANTILE)*100:.0f}%)")

# Build output directories (with full parameter set for consistent cache keys)
output_dirs = analysis.build_analysis_output_dirs(
    base_output_dir=BASE_OUTPUT_DIR,
    dataset_name=DATASET_NAME,
    filter_description=filter_desc,
    resolution=RESOLUTION,
    min_edges=MIN_EDGES,
    selected_languages=SELECTED_LANGUAGES,
    attributes=ATTRIBUTES,
    logspace_lower_bound=LOGSPACE_LOWER_BOUND
)
print(f"✓ Output directory: {output_dirs['base']}")

# Check for cached results
print("\nChecking for cached results...")
retention_results = analysis.load_cached_analysis_results(
    output_dirs, 
    SELECTED_LANGUAGES, 
    ATTRIBUTES
)

if retention_results is None:
    print("No cache found. Running analysis...\n")
    
    retention_results = analysis.run_bias_analysis(
        edges_df=edges_df,
        meta_df=meta_df,
        edge_id_map={
            'source_wikidata_id': 'src',
            'target_wikidata_id': 'trg',
            'weight': 'nij'
        },
        meta_id_col='wikidata_id',
        selected_languages=SELECTED_LANGUAGES,
        min_edges=MIN_EDGES,
        resolution=RESOLUTION,
        filter_zero_weights=True,
        language_col='language_code',
        add_aggregated_all=True,
        pre_transform_filters=[filter_func],
        post_transform_filters=None,
        dataset_label=filter_desc
    )
    
    # Save results with full parameter information
    print("\nSaving results...")
    analysis.save_analysis_results(
        retention_results, 
        output_dirs, 
        SELECTED_LANGUAGES + ['all'], 
        ATTRIBUTES,
        resolution=RESOLUTION,
        min_edges=MIN_EDGES,
        logspace_lower_bound=LOGSPACE_LOWER_BOUND,
        dataset_name=DATASET_NAME,
        filter_description=filter_desc
    )
    print("✓ Results saved")
else:
    print("✓ Using cached results (skipping computation)")

print("\n" + "=" * 80)
print("ANALYSIS COMPLETE")
print("=" * 80)
# Out:
# ================================================================================
# ANALYSIS: Language-specific pageview filtering (quantile=0.8)
# ================================================================================
# INFO: Processing dataframes
# ✓ Created language-specific pageview filter (top 20%)
# ✓ Output directory: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_pageview_q0.8_lang_res50_min500_langs5_attrs3
#
# Checking for cached results...
# No cache found. Running analysis...
# INFO: Loaded 2843871 edges with positive weight
# INFO: Analyzing 6 language(s): ['en', 'de', 'fr', 'it', 'es', 'all']
# INFO: Processing language: en
# INFO: After pre-transform filters for en: 548835 edges remaining
# INFO: Processing language: de
# INFO: After pre-transform filters for de: 86759 edges remaining
# INFO: Processing language: fr
# INFO: After pre-transform filters for fr: 172315 edges remaining
# INFO: Processing language: it
# INFO: After pre-transform filters for it: 119201 edges remaining
# INFO: Processing language: es
# INFO: After pre-transform filters for es: 127524 edges remaining
# INFO: Processing language: all
# INFO: After pre-transform filters for all: 1285569 edges remaining
# INFO: Analysis complete - returning raw retention results
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_pageview_q0.8_lang_res50_min500_langs5_attrs3/auc/auc_en_gender.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_pageview_q0.8_lang_res50_min500_langs5_attrs3/retention_data/retention_curves_en_gender.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_pageview_q0.8_lang_res50_min500_langs5_attrs3/retention_data/node_retention_en_gender.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_pageview_q0.8_lang_res50_min500_langs5_attrs3/auc/auc_en_bigperiod_birth.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_pageview_q0.8_lang_res50_min500_langs5_attrs3/retention_data/retention_curves_en_bigperiod_birth.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_pageview_q0.8_lang_res50_min500_langs5_attrs3/retention_data/node_retention_en_bigperiod_birth.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_pageview_q0.8_lang_res50_min500_langs5_attrs3/auc/auc_en_un_subregion.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_pageview_q0.8_lang_res50_min500_langs5_attrs3/retention_data/retention_curves_en_un_subregion.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_pageview_q0.8_lang_res50_min500_langs5_attrs3/retention_data/node_retention_en_un_subregion.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_pageview_q0.8_lang_res50_min500_langs5_attrs3/auc/auc_de_gender.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_pageview_q0.8_lang_res50_min500_langs5_attrs3/retention_data/retention_curves_de_gender.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_pageview_q0.8_lang_res50_min500_langs5_attrs3/retention_data/node_retention_de_gender.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_pageview_q0.8_lang_res50_min500_langs5_attrs3/auc/auc_de_bigperiod_birth.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_pageview_q0.8_lang_res50_min500_langs5_attrs3/retention_data/retention_curves_de_bigperiod_birth.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_pageview_q0.8_lang_res50_min500_langs5_attrs3/retention_data/node_retention_de_bigperiod_birth.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_pageview_q0.8_lang_res50_min500_langs5_attrs3/auc/auc_de_un_subregion.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_pageview_q0.8_lang_res50_min500_langs5_attrs3/retention_data/retention_curves_de_un_subregion.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_pageview_q0.8_lang_res50_min500_langs5_attrs3/retention_data/node_retention_de_un_subregion.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_pageview_q0.8_lang_res50_min500_langs5_attrs3/auc/auc_fr_gender.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_pageview_q0.8_lang_res50_min500_langs5_attrs3/retention_data/retention_curves_fr_gender.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_pageview_q0.8_lang_res50_min500_langs5_attrs3/retention_data/node_retention_fr_gender.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_pageview_q0.8_lang_res50_min500_langs5_attrs3/auc/auc_fr_bigperiod_birth.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_pageview_q0.8_lang_res50_min500_langs5_attrs3/retention_data/retention_curves_fr_bigperiod_birth.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_pageview_q0.8_lang_res50_min500_langs5_attrs3/retention_data/node_retention_fr_bigperiod_birth.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_pageview_q0.8_lang_res50_min500_langs5_attrs3/auc/auc_fr_un_subregion.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_pageview_q0.8_lang_res50_min500_langs5_attrs3/retention_data/retention_curves_fr_un_subregion.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_pageview_q0.8_lang_res50_min500_langs5_attrs3/retention_data/node_retention_fr_un_subregion.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_pageview_q0.8_lang_res50_min500_langs5_attrs3/auc/auc_it_gender.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_pageview_q0.8_lang_res50_min500_langs5_attrs3/retention_data/retention_curves_it_gender.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_pageview_q0.8_lang_res50_min500_langs5_attrs3/retention_data/node_retention_it_gender.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_pageview_q0.8_lang_res50_min500_langs5_attrs3/auc/auc_it_bigperiod_birth.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_pageview_q0.8_lang_res50_min500_langs5_attrs3/retention_data/retention_curves_it_bigperiod_birth.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_pageview_q0.8_lang_res50_min500_langs5_attrs3/retention_data/node_retention_it_bigperiod_birth.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_pageview_q0.8_lang_res50_min500_langs5_attrs3/auc/auc_it_un_subregion.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_pageview_q0.8_lang_res50_min500_langs5_attrs3/retention_data/retention_curves_it_un_subregion.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_pageview_q0.8_lang_res50_min500_langs5_attrs3/retention_data/node_retention_it_un_subregion.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_pageview_q0.8_lang_res50_min500_langs5_attrs3/auc/auc_es_gender.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_pageview_q0.8_lang_res50_min500_langs5_attrs3/retention_data/retention_curves_es_gender.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_pageview_q0.8_lang_res50_min500_langs5_attrs3/retention_data/node_retention_es_gender.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_pageview_q0.8_lang_res50_min500_langs5_attrs3/auc/auc_es_bigperiod_birth.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_pageview_q0.8_lang_res50_min500_langs5_attrs3/retention_data/retention_curves_es_bigperiod_birth.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_pageview_q0.8_lang_res50_min500_langs5_attrs3/retention_data/node_retention_es_bigperiod_birth.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_pageview_q0.8_lang_res50_min500_langs5_attrs3/auc/auc_es_un_subregion.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_pageview_q0.8_lang_res50_min500_langs5_attrs3/retention_data/retention_curves_es_un_subregion.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_pageview_q0.8_lang_res50_min500_langs5_attrs3/retention_data/node_retention_es_un_subregion.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_pageview_q0.8_lang_res50_min500_langs5_attrs3/auc/auc_all_gender.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_pageview_q0.8_lang_res50_min500_langs5_attrs3/retention_data/retention_curves_all_gender.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_pageview_q0.8_lang_res50_min500_langs5_attrs3/retention_data/node_retention_all_gender.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_pageview_q0.8_lang_res50_min500_langs5_attrs3/auc/auc_all_bigperiod_birth.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_pageview_q0.8_lang_res50_min500_langs5_attrs3/retention_data/retention_curves_all_bigperiod_birth.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_pageview_q0.8_lang_res50_min500_langs5_attrs3/retention_data/node_retention_all_bigperiod_birth.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_pageview_q0.8_lang_res50_min500_langs5_attrs3/auc/auc_all_un_subregion.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_pageview_q0.8_lang_res50_min500_langs5_attrs3/retention_data/retention_curves_all_un_subregion.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_pageview_q0.8_lang_res50_min500_langs5_attrs3/retention_data/node_retention_all_un_subregion.csv
# INFO: Saved cache metadata: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_pageview_q0.8_lang_res50_min500_langs5_attrs3/cache_metadata.json
# Saving results...
# ✓ Results saved
#
# ================================================================================
# ANALYSIS COMPLETE
# ================================================================================

# %% [markdown]
# ## Display Results

# %%
print("\n" + "=" * 80)
print("ANALYSIS RESULTS")
print("=" * 80)

for lang in retention_results:
    print(f"\n{'━'*80}")
    print(f" Language: {lang.upper()}")
    print(f"{'━'*80}")
    
    for attr in retention_results[lang]:
        result_tuple = retention_results[lang][attr]
        if len(result_tuple) == 4:
            edge_results, node_results, auc_matrix, dataset_label = result_tuple
        else:
            edge_results, node_results, auc_matrix = result_tuple
        
        print(f"\n  {attr.upper()} - AUC Matrix:")
        print(f"  {'-'*76}")
        print(auc_matrix.to_string(index=True))
        
        print(f"\n  {attr.upper()} - Edge Pairs Summary:")
        print(f"  {'-'*76}")
        for res in edge_results:
            src, trg = res['pair']
            print(f"    {src:15} → {trg:15}  |  AUC: {res['auc']:.4f}  |  Edges: {res['n_edges']:,}")
        
        if not edge_results:
            print(f"    (No pairs met the minimum threshold of {MIN_EDGES} edges)")
# Out:
# ================================================================================
# ANALYSIS RESULTS
# ================================================================================
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  Language: EN
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#   GENDER - AUC Matrix:
#   ----------------------------------------------------------------------------
#           Female      Male  Other
# Female  0.999933  0.999796    NaN
# Male    0.999900  0.999778    NaN
# Other        NaN       NaN    NaN
#
#   GENDER - Edge Pairs Summary:
#   ----------------------------------------------------------------------------
#     Female          → Female           |  AUC: 0.9999  |  Edges: 49,097
#     Female          → Male             |  AUC: 0.9998  |  Edges: 70,828
#     Male            → Female           |  AUC: 0.9999  |  Edges: 48,967
#     Male            → Male             |  AUC: 0.9998  |  Edges: 379,334
#
#   BIGPERIOD_BIRTH - AUC Matrix:
#   ----------------------------------------------------------------------------
#                  Ancient  Contemporary  Early Modern  Mid Modern  Post-Classical
# Ancient         0.999424      0.999611      0.997777    0.997093        0.999277
# Contemporary    0.998610      0.999916      0.998320    0.999534        0.999533
# Early Modern    0.997542      0.999808      0.999821    0.998724        0.999813
# Mid Modern      0.998542      0.999880      0.999183    0.999618        0.999447
# Post-Classical  0.998932      0.999762      0.999262    0.998484        0.999958
#
#   BIGPERIOD_BIRTH - Edge Pairs Summary:
#   ----------------------------------------------------------------------------
#     Ancient         → Ancient          |  AUC: 0.9994  |  Edges: 9,748
#     Ancient         → Contemporary     |  AUC: 0.9996  |  Edges: 636
#     Ancient         → Early Modern     |  AUC: 0.9978  |  Edges: 574
#     Ancient         → Mid Modern       |  AUC: 0.9971  |  Edges: 675
#     Ancient         → Post-Classical   |  AUC: 0.9993  |  Edges: 838
#     Contemporary    → Ancient          |  AUC: 0.9986  |  Edges: 1,116
#     Contemporary    → Contemporary     |  AUC: 0.9999  |  Edges: 373,717
#     Contemporary    → Early Modern     |  AUC: 0.9983  |  Edges: 3,254
#     Contemporary    → Mid Modern       |  AUC: 0.9995  |  Edges: 31,786
#     Contemporary    → Post-Classical   |  AUC: 0.9995  |  Edges: 1,115
#     Early Modern    → Ancient          |  AUC: 0.9975  |  Edges: 664
#     Early Modern    → Contemporary     |  AUC: 0.9998  |  Edges: 1,364
#     Early Modern    → Early Modern     |  AUC: 0.9998  |  Edges: 11,646
#     Early Modern    → Mid Modern       |  AUC: 0.9987  |  Edges: 3,010
#     Early Modern    → Post-Classical   |  AUC: 0.9998  |  Edges: 1,601
#     Mid Modern      → Ancient          |  AUC: 0.9985  |  Edges: 855
#     Mid Modern      → Contemporary     |  AUC: 0.9999  |  Edges: 17,435
#     Mid Modern      → Early Modern     |  AUC: 0.9992  |  Edges: 4,930
#     Mid Modern      → Mid Modern       |  AUC: 0.9996  |  Edges: 54,976
#     Mid Modern      → Post-Classical   |  AUC: 0.9994  |  Edges: 1,126
#     Post-Classical  → Ancient          |  AUC: 0.9989  |  Edges: 1,145
#     Post-Classical  → Contemporary     |  AUC: 0.9998  |  Edges: 958
#     Post-Classical  → Early Modern     |  AUC: 0.9993  |  Edges: 1,406
#     Post-Classical  → Mid Modern       |  AUC: 0.9985  |  Edges: 984
#     Post-Classical  → Post-Classical   |  AUC: 1.0000  |  Edges: 15,690
#
#   UN_SUBREGION - AUC Matrix:
#   ----------------------------------------------------------------------------
#              Non-Western   Western
# Non-Western     0.999962  0.999690
# Western         0.999912  0.999799
#
#   UN_SUBREGION - Edge Pairs Summary:
#   ----------------------------------------------------------------------------
#     Non-Western     → Non-Western      |  AUC: 1.0000  |  Edges: 33,230
#     Non-Western     → Western          |  AUC: 0.9997  |  Edges: 30,763
#     Western         → Non-Western      |  AUC: 0.9999  |  Edges: 23,881
#     Western         → Western          |  AUC: 0.9998  |  Edges: 459,028
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  Language: DE
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#   GENDER - AUC Matrix:
#   ----------------------------------------------------------------------------
#           Female      Male  Other
# Female  0.999983  0.999759    NaN
# Male    0.999953  0.999614    NaN
# Other        NaN       NaN    NaN
#
#   GENDER - Edge Pairs Summary:
#   ----------------------------------------------------------------------------
#     Female          → Female           |  AUC: 1.0000  |  Edges: 7,429
#     Female          → Male             |  AUC: 0.9998  |  Edges: 13,177
#     Male            → Female           |  AUC: 1.0000  |  Edges: 9,024
#     Male            → Male             |  AUC: 0.9996  |  Edges: 57,043
#
#   BIGPERIOD_BIRTH - AUC Matrix:
#   ----------------------------------------------------------------------------
#                  Ancient  Contemporary  Early Modern  Mid Modern  Post-Classical
# Ancient         0.998889           NaN           NaN         NaN             NaN
# Contemporary         NaN      0.999951      0.999499    0.999283             NaN
# Early Modern         NaN           NaN      0.999836    0.997927             NaN
# Mid Modern           NaN      0.999816      0.999060    0.999266             NaN
# Post-Classical       NaN           NaN           NaN         NaN        0.999938
#
#   BIGPERIOD_BIRTH - Edge Pairs Summary:
#   ----------------------------------------------------------------------------
#     Ancient         → Ancient          |  AUC: 0.9989  |  Edges: 1,574
#     Contemporary    → Contemporary     |  AUC: 1.0000  |  Edges: 56,357
#     Contemporary    → Early Modern     |  AUC: 0.9995  |  Edges: 560
#     Contemporary    → Mid Modern       |  AUC: 0.9993  |  Edges: 5,628
#     Early Modern    → Early Modern     |  AUC: 0.9998  |  Edges: 1,540
#     Early Modern    → Mid Modern       |  AUC: 0.9979  |  Edges: 634
#     Mid Modern      → Contemporary     |  AUC: 0.9998  |  Edges: 3,811
#     Mid Modern      → Early Modern     |  AUC: 0.9991  |  Edges: 950
#     Mid Modern      → Mid Modern       |  AUC: 0.9993  |  Edges: 11,082
#     Post-Classical  → Post-Classical   |  AUC: 0.9999  |  Edges: 1,179
#
#   UN_SUBREGION - AUC Matrix:
#   ----------------------------------------------------------------------------
#              Non-Western   Western
# Non-Western     0.999968  0.999623
# Western         0.999847  0.999699
#
#   UN_SUBREGION - Edge Pairs Summary:
#   ----------------------------------------------------------------------------
#     Non-Western     → Non-Western      |  AUC: 1.0000  |  Edges: 1,692
#     Non-Western     → Western          |  AUC: 0.9996  |  Edges: 3,080
#     Western         → Non-Western      |  AUC: 0.9998  |  Edges: 2,592
#     Western         → Western          |  AUC: 0.9997  |  Edges: 79,226
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  Language: FR
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#   GENDER - AUC Matrix:
#   ----------------------------------------------------------------------------
#           Female      Male  Other
# Female  0.999936  0.999660    NaN
# Male    0.999928  0.999507    NaN
# Other        NaN       NaN    NaN
#
#   GENDER - Edge Pairs Summary:
#   ----------------------------------------------------------------------------
#     Female          → Female           |  AUC: 0.9999  |  Edges: 17,029
#     Female          → Male             |  AUC: 0.9997  |  Edges: 30,848
#     Male            → Female           |  AUC: 0.9999  |  Edges: 16,831
#     Male            → Male             |  AUC: 0.9995  |  Edges: 107,365
#
#   BIGPERIOD_BIRTH - AUC Matrix:
#   ----------------------------------------------------------------------------
#                  Ancient  Contemporary  Early Modern  Mid Modern  Post-Classical
# Ancient         0.999142           NaN           NaN         NaN             NaN
# Contemporary         NaN      0.999861      0.999117    0.998519             NaN
# Early Modern         NaN      0.999839      0.999745    0.997845        0.998908
# Mid Modern           NaN      0.999762      0.998596    0.999033             NaN
# Post-Classical       NaN      0.999811           NaN         NaN        0.999755
#
#   BIGPERIOD_BIRTH - Edge Pairs Summary:
#   ----------------------------------------------------------------------------
#     Ancient         → Ancient          |  AUC: 0.9991  |  Edges: 2,162
#     Contemporary    → Contemporary     |  AUC: 0.9999  |  Edges: 124,482
#     Contemporary    → Early Modern     |  AUC: 0.9991  |  Edges: 1,210
#     Contemporary    → Mid Modern       |  AUC: 0.9985  |  Edges: 9,839
#     Early Modern    → Contemporary     |  AUC: 0.9998  |  Edges: 803
#     Early Modern    → Early Modern     |  AUC: 0.9997  |  Edges: 2,881
#     Early Modern    → Mid Modern       |  AUC: 0.9978  |  Edges: 1,218
#     Early Modern    → Post-Classical   |  AUC: 0.9989  |  Edges: 502
#     Mid Modern      → Contemporary     |  AUC: 0.9998  |  Edges: 5,450
#     Mid Modern      → Early Modern     |  AUC: 0.9986  |  Edges: 1,480
#     Mid Modern      → Mid Modern       |  AUC: 0.9990  |  Edges: 14,452
#     Post-Classical  → Contemporary     |  AUC: 0.9998  |  Edges: 505
#     Post-Classical  → Post-Classical   |  AUC: 0.9998  |  Edges: 2,635
#
#   UN_SUBREGION - AUC Matrix:
#   ----------------------------------------------------------------------------
#              Non-Western   Western
# Non-Western     0.999962  0.999516
# Western         0.999888  0.999601
#
#   UN_SUBREGION - Edge Pairs Summary:
#   ----------------------------------------------------------------------------
#     Non-Western     → Non-Western      |  AUC: 1.0000  |  Edges: 4,664
#     Non-Western     → Western          |  AUC: 0.9995  |  Edges: 8,319
#     Western         → Non-Western      |  AUC: 0.9999  |  Edges: 6,739
#     Western         → Western          |  AUC: 0.9996  |  Edges: 152,379
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  Language: IT
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#   GENDER - AUC Matrix:
#   ----------------------------------------------------------------------------
#           Female      Male  Other
# Female  0.999913  0.999753    NaN
# Male    0.999918  0.999684    NaN
# Other        NaN       NaN    NaN
#
#   GENDER - Edge Pairs Summary:
#   ----------------------------------------------------------------------------
#     Female          → Female           |  AUC: 0.9999  |  Edges: 9,407
#     Female          → Male             |  AUC: 0.9998  |  Edges: 20,337
#     Male            → Female           |  AUC: 0.9999  |  Edges: 9,819
#     Male            → Male             |  AUC: 0.9997  |  Edges: 79,519
#
#   BIGPERIOD_BIRTH - AUC Matrix:
#   ----------------------------------------------------------------------------
#                  Ancient  Contemporary  Early Modern  Mid Modern  Post-Classical
# Ancient         0.999522           NaN           NaN         NaN             NaN
# Contemporary         NaN      0.999881      0.998214    0.999212             NaN
# Early Modern         NaN           NaN      0.999739    0.997567             NaN
# Mid Modern           NaN      0.999772      0.998882    0.999407             NaN
# Post-Classical       NaN           NaN           NaN         NaN        0.999827
#
#   BIGPERIOD_BIRTH - Edge Pairs Summary:
#   ----------------------------------------------------------------------------
#     Ancient         → Ancient          |  AUC: 0.9995  |  Edges: 2,221
#     Contemporary    → Contemporary     |  AUC: 0.9999  |  Edges: 89,033
#     Contemporary    → Early Modern     |  AUC: 0.9982  |  Edges: 1,058
#     Contemporary    → Mid Modern       |  AUC: 0.9992  |  Edges: 5,484
#     Early Modern    → Early Modern     |  AUC: 0.9997  |  Edges: 2,211
#     Early Modern    → Mid Modern       |  AUC: 0.9976  |  Edges: 682
#     Mid Modern      → Contemporary     |  AUC: 0.9998  |  Edges: 2,955
#     Mid Modern      → Early Modern     |  AUC: 0.9989  |  Edges: 990
#     Mid Modern      → Mid Modern       |  AUC: 0.9994  |  Edges: 7,134
#     Post-Classical  → Post-Classical   |  AUC: 0.9998  |  Edges: 2,762
#
#   UN_SUBREGION - AUC Matrix:
#   ----------------------------------------------------------------------------
#              Non-Western   Western
# Non-Western     0.999967  0.999664
# Western         0.999892  0.999725
#
#   UN_SUBREGION - Edge Pairs Summary:
#   ----------------------------------------------------------------------------
#     Non-Western     → Non-Western      |  AUC: 1.0000  |  Edges: 2,251
#     Non-Western     → Western          |  AUC: 0.9997  |  Edges: 4,889
#     Western         → Non-Western      |  AUC: 0.9999  |  Edges: 4,171
#     Western         → Western          |  AUC: 0.9997  |  Edges: 107,732
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  Language: ES
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#   GENDER - AUC Matrix:
#   ----------------------------------------------------------------------------
#           Female      Male  Other
# Female  0.999946  0.999673    NaN
# Male    0.999863  0.999646    NaN
# Other        NaN       NaN    NaN
#
#   GENDER - Edge Pairs Summary:
#   ----------------------------------------------------------------------------
#     Female          → Female           |  AUC: 0.9999  |  Edges: 12,244
#     Female          → Male             |  AUC: 0.9997  |  Edges: 20,604
#     Male            → Female           |  AUC: 0.9999  |  Edges: 12,262
#     Male            → Male             |  AUC: 0.9996  |  Edges: 82,267
#
#   BIGPERIOD_BIRTH - AUC Matrix:
#   ----------------------------------------------------------------------------
#                  Ancient  Contemporary  Early Modern  Mid Modern  Post-Classical
# Ancient         0.999519           NaN           NaN         NaN             NaN
# Contemporary         NaN      0.999842      0.998444    0.998961             NaN
# Early Modern         NaN           NaN      0.999771    0.999505        0.999474
# Mid Modern           NaN      0.999890      0.998420    0.999356             NaN
# Post-Classical       NaN           NaN      0.999147         NaN        0.999863
#
#   BIGPERIOD_BIRTH - Edge Pairs Summary:
#   ----------------------------------------------------------------------------
#     Ancient         → Ancient          |  AUC: 0.9995  |  Edges: 2,446
#     Contemporary    → Contemporary     |  AUC: 0.9998  |  Edges: 89,704
#     Contemporary    → Early Modern     |  AUC: 0.9984  |  Edges: 790
#     Contemporary    → Mid Modern       |  AUC: 0.9990  |  Edges: 6,515
#     Early Modern    → Early Modern     |  AUC: 0.9998  |  Edges: 2,581
#     Early Modern    → Mid Modern       |  AUC: 0.9995  |  Edges: 777
#     Early Modern    → Post-Classical   |  AUC: 0.9995  |  Edges: 655
#     Mid Modern      → Contemporary     |  AUC: 0.9999  |  Edges: 3,143
#     Mid Modern      → Early Modern     |  AUC: 0.9984  |  Edges: 1,244
#     Mid Modern      → Mid Modern       |  AUC: 0.9994  |  Edges: 11,369
#     Post-Classical  → Early Modern     |  AUC: 0.9991  |  Edges: 550
#     Post-Classical  → Post-Classical   |  AUC: 0.9999  |  Edges: 3,721
#
#   UN_SUBREGION - AUC Matrix:
#   ----------------------------------------------------------------------------
#              Non-Western   Western
# Non-Western     0.999960  0.999505
# Western         0.999868  0.999673
#
#   UN_SUBREGION - Edge Pairs Summary:
#   ----------------------------------------------------------------------------
#     Non-Western     → Non-Western      |  AUC: 1.0000  |  Edges: 13,804
#     Non-Western     → Western          |  AUC: 0.9995  |  Edges: 9,348
#     Western         → Non-Western      |  AUC: 0.9999  |  Edges: 5,878
#     Western         → Western          |  AUC: 0.9997  |  Edges: 98,161
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  Language: ALL
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#   GENDER - AUC Matrix:
#   ----------------------------------------------------------------------------
#           Female      Male  Other
# Female  0.999859  0.999337    NaN
# Male    0.999764  0.999270    NaN
# Other        NaN       NaN    NaN
#
#   GENDER - Edge Pairs Summary:
#   ----------------------------------------------------------------------------
#     Female          → Female           |  AUC: 0.9999  |  Edges: 105,026
#     Female          → Male             |  AUC: 0.9993  |  Edges: 179,753
#     Male            → Female           |  AUC: 0.9998  |  Edges: 107,005
#     Male            → Male             |  AUC: 0.9993  |  Edges: 892,592
#
#   BIGPERIOD_BIRTH - AUC Matrix:
#   ----------------------------------------------------------------------------
#                  Ancient  Contemporary  Early Modern  Mid Modern  Post-Classical
# Ancient         0.998445      0.997891      0.992273    0.989260        0.997447
# Contemporary    0.996589      0.999755      0.996961    0.998138        0.998692
# Early Modern    0.994602      0.999507      0.999584    0.996880        0.999134
# Mid Modern      0.993377      0.999622      0.997482    0.998929        0.997612
# Post-Classical  0.997091      0.998968      0.997988    0.995242        0.999860
#
#   BIGPERIOD_BIRTH - Edge Pairs Summary:
#   ----------------------------------------------------------------------------
#     Ancient         → Ancient          |  AUC: 0.9984  |  Edges: 21,911
#     Ancient         → Contemporary     |  AUC: 0.9979  |  Edges: 2,050
#     Ancient         → Early Modern     |  AUC: 0.9923  |  Edges: 1,587
#     Ancient         → Mid Modern       |  AUC: 0.9893  |  Edges: 2,062
#     Ancient         → Post-Classical   |  AUC: 0.9974  |  Edges: 2,263
#     Contemporary    → Ancient          |  AUC: 0.9966  |  Edges: 2,687
#     Contemporary    → Contemporary     |  AUC: 0.9998  |  Edges: 816,006
#     Contemporary    → Early Modern     |  AUC: 0.9970  |  Edges: 9,685
#     Contemporary    → Mid Modern       |  AUC: 0.9981  |  Edges: 80,384
#     Contemporary    → Post-Classical   |  AUC: 0.9987  |  Edges: 3,127
#     Early Modern    → Ancient          |  AUC: 0.9946  |  Edges: 2,132
#     Early Modern    → Contemporary     |  AUC: 0.9995  |  Edges: 4,321
#     Early Modern    → Early Modern     |  AUC: 0.9996  |  Edges: 35,075
#     Early Modern    → Mid Modern       |  AUC: 0.9969  |  Edges: 8,552
#     Early Modern    → Post-Classical   |  AUC: 0.9991  |  Edges: 5,314
#     Mid Modern      → Ancient          |  AUC: 0.9934  |  Edges: 2,460
#     Mid Modern      → Contemporary     |  AUC: 0.9996  |  Edges: 44,587
#     Mid Modern      → Early Modern     |  AUC: 0.9975  |  Edges: 13,550
#     Mid Modern      → Mid Modern       |  AUC: 0.9989  |  Edges: 142,094
#     Mid Modern      → Post-Classical   |  AUC: 0.9976  |  Edges: 3,163
#     Post-Classical  → Ancient          |  AUC: 0.9971  |  Edges: 3,597
#     Post-Classical  → Contemporary     |  AUC: 0.9990  |  Edges: 2,940
#     Post-Classical  → Early Modern     |  AUC: 0.9980  |  Edges: 4,048
#     Post-Classical  → Mid Modern       |  AUC: 0.9952  |  Edges: 3,372
#     Post-Classical  → Post-Classical   |  AUC: 0.9999  |  Edges: 48,055
#
#   UN_SUBREGION - AUC Matrix:
#   ----------------------------------------------------------------------------
#              Non-Western   Western
# Non-Western     0.999928  0.999118
# Western         0.999699  0.999334
#
#   UN_SUBREGION - Edge Pairs Summary:
#   ----------------------------------------------------------------------------
#     Non-Western     → Non-Western      |  AUC: 0.9999  |  Edges: 72,341
#     Non-Western     → Western          |  AUC: 0.9991  |  Edges: 72,007
#     Western         → Non-Western      |  AUC: 0.9997  |  Edges: 55,147
#     Western         → Western          |  AUC: 0.9993  |  Edges: 1,081,915

# %% [markdown]
# ## Results Location

# %%
print(f"Results saved to: {output_dirs['base']}")
print(f"  - AUC matrices: {output_dirs['auc']}")
print(f"  - Retention curves data: {output_dirs['retention_data']}")
print(f"  - Cache metadata: {os.path.join(output_dirs['base'], 'cache_metadata.json')}")
# Out:
# Results saved to: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_pageview_q0.8_lang_res50_min500_langs5_attrs3
#   - AUC matrices: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_pageview_q0.8_lang_res50_min500_langs5_attrs3/auc
#   - Retention curves data: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_pageview_q0.8_lang_res50_min500_langs5_attrs3/retention_data
#   - Cache metadata: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_pageview_q0.8_lang_res50_min500_langs5_attrs3/cache_metadata.json
