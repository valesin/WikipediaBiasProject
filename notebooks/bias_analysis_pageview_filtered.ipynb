# %% [markdown]
# # Wikipedia Bias Analysis: Pageview-Filtered Networks
#
# This notebook analyzes retention bias in Wikipedia link networks filtered by page popularity (pageviews).
#
# ## Filtering Modes
#
# 1. **Language-Specific**: Different pageview thresholds per language edition
# 2. **Global/Multilayer**: Single threshold based on aggregated pageviews across all languages
#
# ## Workflow
#
# 1. **Exploration**: Compare statistics for multiple quantile thresholds
# 2. **Analysis**: Select one threshold and run complete bias analysis
# 3. **Results**: View and save retention curves and AUC matrices
#
# ## Dataset
#
# - **Edges**: Weighted links from DBpedia Spotlight
# - **Metadata**: Demographic attributes (gender, birth year, region)
# - **Pageviews**: Daily average views from Wikipedia API

# %% [markdown]
# ## Setup and Imports

# %%
import os
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import logging

# Add project root to Python path
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

print(f"Project root: {project_root}")

# Configure logging
logging.basicConfig(
    level=logging.INFO,
    format='%(levelname)s: %(message)s'
)

# Import analysis modules
from src import analysis, filters

# Force reload to get latest code changes
import importlib
importlib.reload(analysis)
importlib.reload(filters)

print("✓ Modules imported and reloaded successfully")

# Set visualization defaults
plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette('husl')
# %matplotlib inline

# Helper function
def extract_dataset_name(csv_path):
    """Extract dataset name from CSV filename (without extension)."""
    basename = os.path.basename(csv_path)
    return os.path.splitext(basename)[0]

print("✓ Setup complete")
# Out:
# Project root: /home/vlr/Workspaces/WikipediaBiasProject/PyProject
# ✓ Modules imported and reloaded successfully
# ✓ Setup complete

# %% [markdown]
# ## Configuration
#
# **Modify these variables** to change the analysis parameters.

# %%
# ============================================================================
# DATA PATHS
# ============================================================================

# Edges CSV (update to your most recent SpotlightWeightSource file)
EDGE_CSV = os.path.join(project_root, "data/out/SpotlightWeightSource_0102_0505_fullmatch_corrected.csv")

# Metadata CSV
META_CSV = os.path.join(project_root, "data/entities_filtered_by_languages.csv")

# Pageviews CSV (generated by: python src/main.py pageviews)
PAGEVIEW_CSV = os.path.join(project_root, "data/out/pageviews_2023-01-01_to_2025-12-31.csv")

# Output directory
BASE_OUTPUT_DIR = os.path.join(project_root, "data/out/plots")
os.makedirs(BASE_OUTPUT_DIR, exist_ok=True)

# ============================================================================
# ANALYSIS PARAMETERS
# ============================================================================

# Languages to analyze
SELECTED_LANGUAGES = ['en', 'de', 'fr', 'it', 'es']

# Attributes to analyze
ATTRIBUTES = ['gender', 'un_subregion', 'bigperiod_birth']

# Statistical parameters
MIN_EDGES = 500  # Minimum edges for statistical reliability
RESOLUTION = 50  # Threshold points (higher = more precise but slower)
LOGSPACE_LOWER_BOUND = -14  # Lower bound for logspace threshold calculation

# ============================================================================
# FILTERING MODE
# ============================================================================

# False = Language-specific filtering (different threshold per language)
# True = Global/multilayer filtering (same node set across all languages)
USE_GLOBAL_PAGEVIEWS = False

# ============================================================================
# EXPLORATION: Thresholds to compare
# ============================================================================

# Quantile values to explore (0.8 = top 20%, 0.9 = top 10%, etc.)
EXPLORE_QUANTILES = [0.5, 0.7, 0.8, 0.9]

# ============================================================================
# ANALYSIS: Selected threshold (set after exploring)
# ============================================================================

# Quantile threshold for full analysis
ANALYSIS_QUANTILE = 0.8  # Change this after reviewing exploration results

# Alternative: Use absolute threshold instead of quantile
# ANALYSIS_ABSOLUTE = 1000  # Uncomment and modify analysis code to use this

# ============================================================================

DATASET_NAME = extract_dataset_name(EDGE_CSV)
print(f"Configuration loaded: {len(SELECTED_LANGUAGES)} languages, {len(ATTRIBUTES)} attributes")
print(f"Dataset: {DATASET_NAME}")
print(f"Filtering mode: {'Global/Multilayer' if USE_GLOBAL_PAGEVIEWS else 'Language-Specific'}")
# Out:
# Configuration loaded: 5 languages, 3 attributes
# Dataset: SpotlightWeightSource_0102_0505_fullmatch_corrected
# Filtering mode: Language-Specific

# %% [markdown]
# ## Load Data

# %%
print("Loading data...")
edges_df = pd.read_csv(EDGE_CSV)
meta_df = pd.read_csv(META_CSV)
pageviews_df = pd.read_csv(PAGEVIEW_CSV)

print(f"✓ Loaded {len(edges_df):,} edges")
print(f"✓ Loaded {len(meta_df):,} metadata records")
print(f"✓ Loaded {len(pageviews_df):,} pageview records")

print(f"\nEdge columns: {list(edges_df.columns)}")
print(f"Meta columns: {list(meta_df.columns)}")
print(f"Pageview columns: {list(pageviews_df.columns)}")

print(f"\nPageview statistics:")
print(f"  Min: {pageviews_df['pageviews'].min():.2f}")
print(f"  Median: {pageviews_df['pageviews'].median():.2f}")
print(f"  Mean: {pageviews_df['pageviews'].mean():.2f}")
print(f"  Max: {pageviews_df['pageviews'].max():.2f}")
# Out:
# Loading data...
# ✓ Loaded 12,438,067 edges
# ✓ Loaded 94,403 metadata records
# ✓ Loaded 471,638 pageview records
#
# Edge columns: ['language_code', 'source_wikidata_id', 'target_wikidata_id', 'weight', 'substring']
# Meta columns: ['wikidata_id', 'birth', 'bigperiod_birth', 'un_subregion', 'gender']
# Pageview columns: ['wikidata_id', 'language_code', 'pageviews']
#
# Pageview statistics:
#   Min: 0.00
#   Median: 9.00
#   Mean: 123.06
#   Max: 145465.00

# %% [markdown]
# ---
# # Exploration: Compare Thresholds
#
# This section compares different quantile thresholds **without running the full analysis**.
#
# Review the statistics below, then:
# 1. Set `ANALYSIS_QUANTILE` in the configuration cell above
# 2. Rerun from the Analysis section

# %%
print("=" * 80)
print("EXPLORATION: Comparing Quantile Thresholds")
print("=" * 80)
print(f"Filtering mode: {'Global (multilayer)' if USE_GLOBAL_PAGEVIEWS else 'Language-specific'}\n")

# Aggregate pageviews if using global mode
if USE_GLOBAL_PAGEVIEWS:
    print("Aggregating pageviews across all languages...")
    pageviews_agg = pageviews_df.groupby('wikidata_id')['pageviews'].sum().reset_index()
    pageviews_agg.columns = ['wikidata_id', 'pageviews_total']
    print(f"✓ Aggregated pageviews for {len(pageviews_agg):,} unique entities\n")
    
    # Show aggregated pageview statistics
    print("Aggregated pageview statistics:")
    print(f"  Min: {pageviews_agg['pageviews_total'].min():.2f}")
    print(f"  Median: {pageviews_agg['pageviews_total'].median():.2f}")
    print(f"  Mean: {pageviews_agg['pageviews_total'].mean():.2f}")
    print(f"  Max: {pageviews_agg['pageviews_total'].max():.2f}")
    print()
else:
    pageviews_agg = pageviews_df

# Compare quantiles
results_summary = []

for quantile in EXPLORE_QUANTILES:
    print(f"\nQuantile {quantile:.2f} (top {(1-quantile)*100:.0f}%)")
    print("-" * 50)
    
    # Calculate threshold
    if USE_GLOBAL_PAGEVIEWS:
        threshold = pageviews_agg['pageviews_total'].quantile(quantile)
        pageviews_col = 'pageviews_total'
    else:
        threshold = pageviews_df['pageviews'].quantile(quantile)
        pageviews_col = 'pageviews'
    
    print(f"  Threshold value: {threshold:.2f} daily views")
    
    # Count retained entities
    if USE_GLOBAL_PAGEVIEWS:
        retained_entities = pageviews_agg[pageviews_agg[pageviews_col] >= threshold]['wikidata_id'].unique()
        total_entities = pageviews_agg['wikidata_id'].nunique()
    else:
        retained_entities = pageviews_df[pageviews_df[pageviews_col] >= threshold]['wikidata_id'].unique()
        total_entities = pageviews_df['wikidata_id'].nunique()
    
    n_retained = len(retained_entities)
    pct_retained = (n_retained / total_entities) * 100
    
    print(f"  Entities retained: {n_retained:,} / {total_entities:,} ({pct_retained:.1f}%)")
    
    # Calculate actual edge retention (both source AND target must be retained)
    retained_set = set(retained_entities)
    
    # Filter edges: keep only if both source and target are in retained set
    edges_retained = edges_df[
        edges_df['source_wikidata_id'].isin(retained_set) & 
        edges_df['target_wikidata_id'].isin(retained_set)
    ]
    
    n_edges_retained = len(edges_retained)
    edge_retention_rate = (n_edges_retained / len(edges_df)) * 100
    
    print(f"  Edges retained: {n_edges_retained:,} / {len(edges_df):,} ({edge_retention_rate:.1f}%)")
    
    results_summary.append({
        'quantile': quantile,
        'threshold': threshold,
        'entities_retained': n_retained,
        'entities_pct': pct_retained,
        'edges_retained': n_edges_retained,
        'edges_pct': edge_retention_rate
    })

# Summary table
print("\n" + "=" * 80)
print("SUMMARY TABLE")
print("=" * 80)
summary_df = pd.DataFrame(results_summary)
summary_df.columns = ['Quantile', 'Threshold', 'Entities', 'Entities %', 'Edges', 'Edges %']
print(summary_df.to_string(index=False))

print("\n" + "=" * 80)
print("Based on these statistics, set ANALYSIS_QUANTILE in the configuration cell above.")
print("Then rerun from the Analysis section below.")
print("=" * 80)
# Out:
# ================================================================================
# EXPLORATION: Comparing Quantile Thresholds
# ================================================================================
# Filtering mode: Language-specific
#
#
# Quantile 0.50 (top 50%)
# --------------------------------------------------
#   Threshold value: 9.00 daily views
#   Entities retained: 82,342 / 94,403 (87.2%)
#   Edges retained: 11,397,397 / 12,438,067 (91.6%)
#
# Quantile 0.70 (top 30%)
# --------------------------------------------------
#   Threshold value: 28.00 daily views
#   Entities retained: 63,024 / 94,403 (66.8%)
#   Edges retained: 9,133,564 / 12,438,067 (73.4%)
#
# Quantile 0.80 (top 20%)
# --------------------------------------------------
#   Threshold value: 60.00 daily views
#   Entities retained: 48,797 / 94,403 (51.7%)
#   Edges retained: 6,926,212 / 12,438,067 (55.7%)
#
# Quantile 0.90 (top 10%)
# --------------------------------------------------
#   Threshold value: 181.00 daily views
#   Entities retained: 30,118 / 94,403 (31.9%)
#   Edges retained: 4,118,532 / 12,438,067 (33.1%)
#
# ================================================================================
# SUMMARY TABLE
# ================================================================================
#  Quantile  Threshold  Entities  Entities %    Edges   Edges %
#       0.5        9.0     82342   87.223923 11397397 91.633185
#       0.7       28.0     63024   66.760590  9133564 73.432343
#       0.8       60.0     48797   51.690095  6926212 55.685598
#       0.9      181.0     30118   31.903647  4118532 33.112316
#
# ================================================================================
# Based on these statistics, set ANALYSIS_QUANTILE in the configuration cell above.
# Then rerun from the Analysis section below.
# ================================================================================

# %% [markdown]
# ---
# # Analysis: Run Bias Analysis with Selected Threshold
#
# This section runs the complete bias analysis with the selected quantile threshold.

# %%
print("=" * 80)
if USE_GLOBAL_PAGEVIEWS:
    print(f"ANALYSIS: Global pageview filtering (quantile={ANALYSIS_QUANTILE})")
    filter_desc = f"pageview_q{ANALYSIS_QUANTILE}_global"
else:
    print(f"ANALYSIS: Language-specific pageview filtering (quantile={ANALYSIS_QUANTILE})")
    filter_desc = f"pageview_q{ANALYSIS_QUANTILE}_lang"
print("=" * 80)

# Build filter function
if USE_GLOBAL_PAGEVIEWS:
    filter_func = filters.restrict_by_pageviews_quantile_global(pageviews_df, ANALYSIS_QUANTILE)
    print(f"✓ Created global pageview filter (top {(1-ANALYSIS_QUANTILE)*100:.0f}%)")
else:
    filter_func = filters.restrict_by_pageviews_quantile(pageviews_df, ANALYSIS_QUANTILE)
    print(f"✓ Created language-specific pageview filter (top {(1-ANALYSIS_QUANTILE)*100:.0f}%)")

# Build output directories (with full parameter set for consistent cache keys)
output_dirs = analysis.build_analysis_output_dirs(
    base_output_dir=BASE_OUTPUT_DIR,
    dataset_name=DATASET_NAME,
    filter_description=filter_desc,
    resolution=RESOLUTION,
    min_edges=MIN_EDGES,
    selected_languages=SELECTED_LANGUAGES,
    attributes=ATTRIBUTES,
    logspace_lower_bound=LOGSPACE_LOWER_BOUND
)
print(f"✓ Output directory: {output_dirs['base']}")

# Check for cached results
print("\nChecking for cached results...")
retention_results = analysis.load_cached_analysis_results(
    output_dirs, 
    SELECTED_LANGUAGES, 
    ATTRIBUTES
)

if retention_results is None:
    print("No cache found. Running analysis...\n")
    
    retention_results = analysis.run_bias_analysis(
        edges_df=edges_df,
        meta_df=meta_df,
        edge_id_map={
            'source_wikidata_id': 'src',
            'target_wikidata_id': 'trg',
            'weight': 'nij'
        },
        meta_id_col='wikidata_id',
        selected_languages=SELECTED_LANGUAGES,
        min_edges=MIN_EDGES,
        resolution=RESOLUTION,
        filter_zero_weights=True,
        language_col='language_code',
        add_aggregated_all=True,
        pre_transform_filters=[filter_func],
        post_transform_filters=None,
        dataset_label=filter_desc
    )
    
    # Save results with full parameter information
    print("\nSaving results...")
    analysis.save_analysis_results(
        retention_results, 
        output_dirs, 
        SELECTED_LANGUAGES + ['all'], 
        ATTRIBUTES,
        resolution=RESOLUTION,
        min_edges=MIN_EDGES,
        logspace_lower_bound=LOGSPACE_LOWER_BOUND,
        dataset_name=DATASET_NAME,
        filter_description=filter_desc
    )
    print("✓ Results saved")
else:
    print("✓ Using cached results (skipping computation)")

print("\n" + "=" * 80)
print("ANALYSIS COMPLETE")
print("=" * 80)
# Out:
# ================================================================================
# ANALYSIS: Language-specific pageview filtering (quantile=0.8)
# ================================================================================
# ✓ Created language-specific pageview filter (top 20%)
# ✓ Output directory: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_fullmatch_corrected_pageview_q0.8_lang_res50_min500_langs5_attrs3
#
# Checking for cached results...
# No cache found. Running analysis...
# INFO: Processing dataframes
# INFO: Loaded 2831950 edges with positive weight
# INFO: Analyzing 6 language(s): ['en', 'de', 'fr', 'it', 'es', 'all']
# INFO: Processing language: en
# INFO: After pre-transform filters for en: 545594 edges remaining
# INFO: Processing language: de
# INFO: After pre-transform filters for de: 86601 edges remaining
# INFO: Processing language: fr
# INFO: After pre-transform filters for fr: 172092 edges remaining
# INFO: Processing language: it
# INFO: After pre-transform filters for it: 118799 edges remaining
# INFO: Processing language: es
# INFO: After pre-transform filters for es: 127077 edges remaining
# INFO: Processing language: all
# INFO: After pre-transform filters for all: 1280641 edges remaining
# INFO: Analysis complete - returning raw retention results
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_fullmatch_corrected_pageview_q0.8_lang_res50_min500_langs5_attrs3/auc/auc_en_gender.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_fullmatch_corrected_pageview_q0.8_lang_res50_min500_langs5_attrs3/retention_data/retention_curves_en_gender.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_fullmatch_corrected_pageview_q0.8_lang_res50_min500_langs5_attrs3/retention_data/node_retention_en_gender.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_fullmatch_corrected_pageview_q0.8_lang_res50_min500_langs5_attrs3/auc/auc_en_bigperiod_birth.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_fullmatch_corrected_pageview_q0.8_lang_res50_min500_langs5_attrs3/retention_data/retention_curves_en_bigperiod_birth.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_fullmatch_corrected_pageview_q0.8_lang_res50_min500_langs5_attrs3/retention_data/node_retention_en_bigperiod_birth.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_fullmatch_corrected_pageview_q0.8_lang_res50_min500_langs5_attrs3/auc/auc_en_un_subregion.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_fullmatch_corrected_pageview_q0.8_lang_res50_min500_langs5_attrs3/retention_data/retention_curves_en_un_subregion.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_fullmatch_corrected_pageview_q0.8_lang_res50_min500_langs5_attrs3/retention_data/node_retention_en_un_subregion.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_fullmatch_corrected_pageview_q0.8_lang_res50_min500_langs5_attrs3/auc/auc_de_gender.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_fullmatch_corrected_pageview_q0.8_lang_res50_min500_langs5_attrs3/retention_data/retention_curves_de_gender.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_fullmatch_corrected_pageview_q0.8_lang_res50_min500_langs5_attrs3/retention_data/node_retention_de_gender.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_fullmatch_corrected_pageview_q0.8_lang_res50_min500_langs5_attrs3/auc/auc_de_bigperiod_birth.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_fullmatch_corrected_pageview_q0.8_lang_res50_min500_langs5_attrs3/retention_data/retention_curves_de_bigperiod_birth.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_fullmatch_corrected_pageview_q0.8_lang_res50_min500_langs5_attrs3/retention_data/node_retention_de_bigperiod_birth.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_fullmatch_corrected_pageview_q0.8_lang_res50_min500_langs5_attrs3/auc/auc_de_un_subregion.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_fullmatch_corrected_pageview_q0.8_lang_res50_min500_langs5_attrs3/retention_data/retention_curves_de_un_subregion.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_fullmatch_corrected_pageview_q0.8_lang_res50_min500_langs5_attrs3/retention_data/node_retention_de_un_subregion.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_fullmatch_corrected_pageview_q0.8_lang_res50_min500_langs5_attrs3/auc/auc_fr_gender.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_fullmatch_corrected_pageview_q0.8_lang_res50_min500_langs5_attrs3/retention_data/retention_curves_fr_gender.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_fullmatch_corrected_pageview_q0.8_lang_res50_min500_langs5_attrs3/retention_data/node_retention_fr_gender.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_fullmatch_corrected_pageview_q0.8_lang_res50_min500_langs5_attrs3/auc/auc_fr_bigperiod_birth.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_fullmatch_corrected_pageview_q0.8_lang_res50_min500_langs5_attrs3/retention_data/retention_curves_fr_bigperiod_birth.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_fullmatch_corrected_pageview_q0.8_lang_res50_min500_langs5_attrs3/retention_data/node_retention_fr_bigperiod_birth.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_fullmatch_corrected_pageview_q0.8_lang_res50_min500_langs5_attrs3/auc/auc_fr_un_subregion.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_fullmatch_corrected_pageview_q0.8_lang_res50_min500_langs5_attrs3/retention_data/retention_curves_fr_un_subregion.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_fullmatch_corrected_pageview_q0.8_lang_res50_min500_langs5_attrs3/retention_data/node_retention_fr_un_subregion.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_fullmatch_corrected_pageview_q0.8_lang_res50_min500_langs5_attrs3/auc/auc_it_gender.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_fullmatch_corrected_pageview_q0.8_lang_res50_min500_langs5_attrs3/retention_data/retention_curves_it_gender.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_fullmatch_corrected_pageview_q0.8_lang_res50_min500_langs5_attrs3/retention_data/node_retention_it_gender.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_fullmatch_corrected_pageview_q0.8_lang_res50_min500_langs5_attrs3/auc/auc_it_bigperiod_birth.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_fullmatch_corrected_pageview_q0.8_lang_res50_min500_langs5_attrs3/retention_data/retention_curves_it_bigperiod_birth.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_fullmatch_corrected_pageview_q0.8_lang_res50_min500_langs5_attrs3/retention_data/node_retention_it_bigperiod_birth.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_fullmatch_corrected_pageview_q0.8_lang_res50_min500_langs5_attrs3/auc/auc_it_un_subregion.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_fullmatch_corrected_pageview_q0.8_lang_res50_min500_langs5_attrs3/retention_data/retention_curves_it_un_subregion.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_fullmatch_corrected_pageview_q0.8_lang_res50_min500_langs5_attrs3/retention_data/node_retention_it_un_subregion.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_fullmatch_corrected_pageview_q0.8_lang_res50_min500_langs5_attrs3/auc/auc_es_gender.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_fullmatch_corrected_pageview_q0.8_lang_res50_min500_langs5_attrs3/retention_data/retention_curves_es_gender.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_fullmatch_corrected_pageview_q0.8_lang_res50_min500_langs5_attrs3/retention_data/node_retention_es_gender.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_fullmatch_corrected_pageview_q0.8_lang_res50_min500_langs5_attrs3/auc/auc_es_bigperiod_birth.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_fullmatch_corrected_pageview_q0.8_lang_res50_min500_langs5_attrs3/retention_data/retention_curves_es_bigperiod_birth.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_fullmatch_corrected_pageview_q0.8_lang_res50_min500_langs5_attrs3/retention_data/node_retention_es_bigperiod_birth.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_fullmatch_corrected_pageview_q0.8_lang_res50_min500_langs5_attrs3/auc/auc_es_un_subregion.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_fullmatch_corrected_pageview_q0.8_lang_res50_min500_langs5_attrs3/retention_data/retention_curves_es_un_subregion.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_fullmatch_corrected_pageview_q0.8_lang_res50_min500_langs5_attrs3/retention_data/node_retention_es_un_subregion.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_fullmatch_corrected_pageview_q0.8_lang_res50_min500_langs5_attrs3/auc/auc_all_gender.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_fullmatch_corrected_pageview_q0.8_lang_res50_min500_langs5_attrs3/retention_data/retention_curves_all_gender.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_fullmatch_corrected_pageview_q0.8_lang_res50_min500_langs5_attrs3/retention_data/node_retention_all_gender.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_fullmatch_corrected_pageview_q0.8_lang_res50_min500_langs5_attrs3/auc/auc_all_bigperiod_birth.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_fullmatch_corrected_pageview_q0.8_lang_res50_min500_langs5_attrs3/retention_data/retention_curves_all_bigperiod_birth.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_fullmatch_corrected_pageview_q0.8_lang_res50_min500_langs5_attrs3/retention_data/node_retention_all_bigperiod_birth.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_fullmatch_corrected_pageview_q0.8_lang_res50_min500_langs5_attrs3/auc/auc_all_un_subregion.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_fullmatch_corrected_pageview_q0.8_lang_res50_min500_langs5_attrs3/retention_data/retention_curves_all_un_subregion.csv
# INFO: Saved: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_fullmatch_corrected_pageview_q0.8_lang_res50_min500_langs5_attrs3/retention_data/node_retention_all_un_subregion.csv
# INFO: Saved cache metadata: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_fullmatch_corrected_pageview_q0.8_lang_res50_min500_langs5_attrs3/cache_metadata.json
# Saving results...
# ✓ Results saved
#
# ================================================================================
# ANALYSIS COMPLETE
# ================================================================================

# %% [markdown]
# ## Display Results

# %%
print("\n" + "=" * 80)
print("ANALYSIS RESULTS")
print("=" * 80)

for lang in retention_results:
    print(f"\n{'━'*80}")
    print(f" Language: {lang.upper()}")
    print(f"{'━'*80}")
    
    for attr in retention_results[lang]:
        result_tuple = retention_results[lang][attr]
        if len(result_tuple) == 4:
            edge_results, node_results, auc_matrix, dataset_label = result_tuple
        else:
            edge_results, node_results, auc_matrix = result_tuple
        
        print(f"\n  {attr.upper()} - AUC Matrix:")
        print(f"  {'-'*76}")
        print(auc_matrix.to_string(index=True))
        
        print(f"\n  {attr.upper()} - Edge Pairs Summary:")
        print(f"  {'-'*76}")
        for res in edge_results:
            src, trg = res['pair']
            print(f"    {src:15} → {trg:15}  |  AUC: {res['auc']:.4f}  |  Edges: {res['n_edges']:,}")
        
        if not edge_results:
            print(f"    (No pairs met the minimum threshold of {MIN_EDGES} edges)")
# Out:
# ================================================================================
# ANALYSIS RESULTS
# ================================================================================
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  Language: EN
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#   GENDER - AUC Matrix:
#   ----------------------------------------------------------------------------
#           Female      Male  Other
# Female  0.999941  0.999839    NaN
# Male    0.999928  0.999837    NaN
# Other        NaN       NaN    NaN
#
#   GENDER - Edge Pairs Summary:
#   ----------------------------------------------------------------------------
#     Female          → Female           |  AUC: 0.9999  |  Edges: 48,610
#     Female          → Male             |  AUC: 0.9998  |  Edges: 70,717
#     Male            → Female           |  AUC: 0.9999  |  Edges: 48,879
#     Male            → Male             |  AUC: 0.9998  |  Edges: 376,783
#
#   BIGPERIOD_BIRTH - AUC Matrix:
#   ----------------------------------------------------------------------------
#                  Ancient  Contemporary  Early Modern  Mid Modern  Post-Classical
# Ancient         0.999482      0.999640      0.998157    0.997848        0.999537
# Contemporary    0.998960      0.999931      0.998746    0.999638        0.999709
# Early Modern    0.998870      0.999917      0.999915    0.999332        0.999902
# Mid Modern      0.998837      0.999921      0.999385    0.999727        0.999685
# Post-Classical  0.999215      0.999856      0.999538    0.999063        0.999971
#
#   BIGPERIOD_BIRTH - Edge Pairs Summary:
#   ----------------------------------------------------------------------------
#     Ancient         → Ancient          |  AUC: 0.9995  |  Edges: 9,642
#     Ancient         → Contemporary     |  AUC: 0.9996  |  Edges: 636
#     Ancient         → Early Modern     |  AUC: 0.9982  |  Edges: 574
#     Ancient         → Mid Modern       |  AUC: 0.9978  |  Edges: 675
#     Ancient         → Post-Classical   |  AUC: 0.9995  |  Edges: 837
#     Contemporary    → Ancient          |  AUC: 0.9990  |  Edges: 1,115
#     Contemporary    → Contemporary     |  AUC: 0.9999  |  Edges: 372,047
#     Contemporary    → Early Modern     |  AUC: 0.9987  |  Edges: 3,245
#     Contemporary    → Mid Modern       |  AUC: 0.9996  |  Edges: 31,736
#     Contemporary    → Post-Classical   |  AUC: 0.9997  |  Edges: 1,113
#     Early Modern    → Ancient          |  AUC: 0.9989  |  Edges: 661
#     Early Modern    → Contemporary     |  AUC: 0.9999  |  Edges: 1,361
#     Early Modern    → Early Modern     |  AUC: 0.9999  |  Edges: 11,455
#     Early Modern    → Mid Modern       |  AUC: 0.9993  |  Edges: 2,978
#     Early Modern    → Post-Classical   |  AUC: 0.9999  |  Edges: 1,580
#     Mid Modern      → Ancient          |  AUC: 0.9988  |  Edges: 855
#     Mid Modern      → Contemporary     |  AUC: 0.9999  |  Edges: 17,413
#     Mid Modern      → Early Modern     |  AUC: 0.9994  |  Edges: 4,897
#     Mid Modern      → Mid Modern       |  AUC: 0.9997  |  Edges: 54,407
#     Mid Modern      → Post-Classical   |  AUC: 0.9997  |  Edges: 1,123
#     Post-Classical  → Ancient          |  AUC: 0.9992  |  Edges: 1,141
#     Post-Classical  → Contemporary     |  AUC: 0.9999  |  Edges: 951
#     Post-Classical  → Early Modern     |  AUC: 0.9995  |  Edges: 1,383
#     Post-Classical  → Mid Modern       |  AUC: 0.9991  |  Edges: 975
#     Post-Classical  → Post-Classical   |  AUC: 1.0000  |  Edges: 15,304
#
#   UN_SUBREGION - AUC Matrix:
#   ----------------------------------------------------------------------------
#              Non-Western   Western
# Non-Western     0.999975  0.999791
# Western         0.999940  0.999848
#
#   UN_SUBREGION - Edge Pairs Summary:
#   ----------------------------------------------------------------------------
#     Non-Western     → Non-Western      |  AUC: 1.0000  |  Edges: 32,630
#     Non-Western     → Western          |  AUC: 0.9998  |  Edges: 30,743
#     Western         → Non-Western      |  AUC: 0.9999  |  Edges: 23,865
#     Western         → Western          |  AUC: 0.9998  |  Edges: 456,442
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  Language: DE
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#   GENDER - AUC Matrix:
#   ----------------------------------------------------------------------------
#           Female      Male  Other
# Female  0.999981  0.999767    NaN
# Male    0.999957  0.999663    NaN
# Other        NaN       NaN    NaN
#
#   GENDER - Edge Pairs Summary:
#   ----------------------------------------------------------------------------
#     Female          → Female           |  AUC: 1.0000  |  Edges: 7,398
#     Female          → Male             |  AUC: 0.9998  |  Edges: 13,168
#     Male            → Female           |  AUC: 1.0000  |  Edges: 9,015
#     Male            → Male             |  AUC: 0.9997  |  Edges: 56,935
#
#   BIGPERIOD_BIRTH - AUC Matrix:
#   ----------------------------------------------------------------------------
#                 Ancient  Contemporary  Early Modern  Mid Modern  Post-Classical
# Ancient         0.99895           NaN           NaN         NaN             NaN
# Contemporary        NaN      0.999953      0.999512    0.999363             NaN
# Early Modern        NaN           NaN      0.999884    0.998659             NaN
# Mid Modern          NaN      0.999846      0.999188    0.999345             NaN
# Post-Classical      NaN           NaN           NaN         NaN        0.999935
#
#   BIGPERIOD_BIRTH - Edge Pairs Summary:
#   ----------------------------------------------------------------------------
#     Ancient         → Ancient          |  AUC: 0.9989  |  Edges: 1,570
#     Contemporary    → Contemporary     |  AUC: 1.0000  |  Edges: 56,261
#     Contemporary    → Early Modern     |  AUC: 0.9995  |  Edges: 560
#     Contemporary    → Mid Modern       |  AUC: 0.9994  |  Edges: 5,619
#     Early Modern    → Early Modern     |  AUC: 0.9999  |  Edges: 1,535
#     Early Modern    → Mid Modern       |  AUC: 0.9987  |  Edges: 633
#     Mid Modern      → Contemporary     |  AUC: 0.9998  |  Edges: 3,809
#     Mid Modern      → Early Modern     |  AUC: 0.9992  |  Edges: 947
#     Mid Modern      → Mid Modern       |  AUC: 0.9993  |  Edges: 11,052
#     Post-Classical  → Post-Classical   |  AUC: 0.9999  |  Edges: 1,176
#
#   UN_SUBREGION - AUC Matrix:
#   ----------------------------------------------------------------------------
#              Non-Western   Western
# Non-Western     0.999974  0.999635
# Western         0.999918  0.999732
#
#   UN_SUBREGION - Edge Pairs Summary:
#   ----------------------------------------------------------------------------
#     Non-Western     → Non-Western      |  AUC: 1.0000  |  Edges: 1,681
#     Non-Western     → Western          |  AUC: 0.9996  |  Edges: 3,080
#     Western         → Non-Western      |  AUC: 0.9999  |  Edges: 2,592
#     Western         → Western          |  AUC: 0.9997  |  Edges: 79,080
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  Language: FR
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#   GENDER - AUC Matrix:
#   ----------------------------------------------------------------------------
#           Female      Male  Other
# Female  0.999939  0.999683    NaN
# Male    0.999934  0.999541    NaN
# Other        NaN       NaN    NaN
#
#   GENDER - Edge Pairs Summary:
#   ----------------------------------------------------------------------------
#     Female          → Female           |  AUC: 0.9999  |  Edges: 16,991
#     Female          → Male             |  AUC: 0.9997  |  Edges: 30,843
#     Male            → Female           |  AUC: 0.9999  |  Edges: 16,822
#     Male            → Male             |  AUC: 0.9995  |  Edges: 107,194
#
#   BIGPERIOD_BIRTH - AUC Matrix:
#   ----------------------------------------------------------------------------
#                  Ancient  Contemporary  Early Modern  Mid Modern  Post-Classical
# Ancient         0.999165           NaN           NaN         NaN             NaN
# Contemporary         NaN      0.999872      0.999092    0.998618             NaN
# Early Modern         NaN      0.999858      0.999763    0.998006             NaN
# Mid Modern           NaN      0.999777      0.998559    0.999101             NaN
# Post-Classical       NaN      0.999814           NaN         NaN        0.999805
#
#   BIGPERIOD_BIRTH - Edge Pairs Summary:
#   ----------------------------------------------------------------------------
#     Ancient         → Ancient          |  AUC: 0.9992  |  Edges: 2,159
#     Contemporary    → Contemporary     |  AUC: 0.9999  |  Edges: 124,380
#     Contemporary    → Early Modern     |  AUC: 0.9991  |  Edges: 1,207
#     Contemporary    → Mid Modern       |  AUC: 0.9986  |  Edges: 9,828
#     Early Modern    → Contemporary     |  AUC: 0.9999  |  Edges: 803
#     Early Modern    → Early Modern     |  AUC: 0.9998  |  Edges: 2,861
#     Early Modern    → Mid Modern       |  AUC: 0.9980  |  Edges: 1,217
#     Mid Modern      → Contemporary     |  AUC: 0.9998  |  Edges: 5,449
#     Mid Modern      → Early Modern     |  AUC: 0.9986  |  Edges: 1,476
#     Mid Modern      → Mid Modern       |  AUC: 0.9991  |  Edges: 14,412
#     Post-Classical  → Contemporary     |  AUC: 0.9998  |  Edges: 505
#     Post-Classical  → Post-Classical   |  AUC: 0.9998  |  Edges: 2,611
#
#   UN_SUBREGION - AUC Matrix:
#   ----------------------------------------------------------------------------
#              Non-Western   Western
# Non-Western     0.999962  0.999585
# Western         0.999903  0.999627
#
#   UN_SUBREGION - Edge Pairs Summary:
#   ----------------------------------------------------------------------------
#     Non-Western     → Non-Western      |  AUC: 1.0000  |  Edges: 4,628
#     Non-Western     → Western          |  AUC: 0.9996  |  Edges: 8,318
#     Western         → Non-Western      |  AUC: 0.9999  |  Edges: 6,739
#     Western         → Western          |  AUC: 0.9996  |  Edges: 152,193
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  Language: IT
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#   GENDER - AUC Matrix:
#   ----------------------------------------------------------------------------
#           Female      Male  Other
# Female  0.999915  0.999770    NaN
# Male    0.999940  0.999749    NaN
# Other        NaN       NaN    NaN
#
#   GENDER - Edge Pairs Summary:
#   ----------------------------------------------------------------------------
#     Female          → Female           |  AUC: 0.9999  |  Edges: 9,371
#     Female          → Male             |  AUC: 0.9998  |  Edges: 20,320
#     Male            → Female           |  AUC: 0.9999  |  Edges: 9,787
#     Male            → Male             |  AUC: 0.9997  |  Edges: 79,202
#
#   BIGPERIOD_BIRTH - AUC Matrix:
#   ----------------------------------------------------------------------------
#                  Ancient  Contemporary  Early Modern  Mid Modern  Post-Classical
# Ancient         0.999714           NaN           NaN         NaN             NaN
# Contemporary         NaN      0.999885      0.998352    0.999372             NaN
# Early Modern         NaN           NaN      0.999779    0.998467             NaN
# Mid Modern           NaN      0.999843      0.999299    0.999633             NaN
# Post-Classical       NaN           NaN           NaN         NaN        0.999845
#
#   BIGPERIOD_BIRTH - Edge Pairs Summary:
#   ----------------------------------------------------------------------------
#     Ancient         → Ancient          |  AUC: 0.9997  |  Edges: 2,191
#     Contemporary    → Contemporary     |  AUC: 0.9999  |  Edges: 88,927
#     Contemporary    → Early Modern     |  AUC: 0.9984  |  Edges: 1,058
#     Contemporary    → Mid Modern       |  AUC: 0.9994  |  Edges: 5,475
#     Early Modern    → Early Modern     |  AUC: 0.9998  |  Edges: 2,160
#     Early Modern    → Mid Modern       |  AUC: 0.9985  |  Edges: 669
#     Mid Modern      → Contemporary     |  AUC: 0.9998  |  Edges: 2,949
#     Mid Modern      → Early Modern     |  AUC: 0.9993  |  Edges: 981
#     Mid Modern      → Mid Modern       |  AUC: 0.9996  |  Edges: 7,037
#     Post-Classical  → Post-Classical   |  AUC: 0.9998  |  Edges: 2,698
#
#   UN_SUBREGION - AUC Matrix:
#   ----------------------------------------------------------------------------
#              Non-Western   Western
# Non-Western     0.999976  0.999715
# Western         0.999906  0.999776
#
#   UN_SUBREGION - Edge Pairs Summary:
#   ----------------------------------------------------------------------------
#     Non-Western     → Non-Western      |  AUC: 1.0000  |  Edges: 2,227
#     Non-Western     → Western          |  AUC: 0.9997  |  Edges: 4,888
#     Western         → Non-Western      |  AUC: 0.9999  |  Edges: 4,166
#     Western         → Western          |  AUC: 0.9998  |  Edges: 107,361
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  Language: ES
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#   GENDER - AUC Matrix:
#   ----------------------------------------------------------------------------
#           Female      Male  Other
# Female  0.999947  0.999688    NaN
# Male    0.999900  0.999684    NaN
# Other        NaN       NaN    NaN
#
#   GENDER - Edge Pairs Summary:
#   ----------------------------------------------------------------------------
#     Female          → Female           |  AUC: 0.9999  |  Edges: 12,198
#     Female          → Male             |  AUC: 0.9997  |  Edges: 20,565
#     Male            → Female           |  AUC: 0.9999  |  Edges: 12,247
#     Male            → Male             |  AUC: 0.9997  |  Edges: 81,920
#
#   BIGPERIOD_BIRTH - AUC Matrix:
#   ----------------------------------------------------------------------------
#                 Ancient  Contemporary  Early Modern  Mid Modern  Post-Classical
# Ancient         0.99949           NaN           NaN         NaN             NaN
# Contemporary        NaN      0.999844      0.998432    0.999015             NaN
# Early Modern        NaN           NaN      0.999881    0.999570        0.999861
# Mid Modern          NaN      0.999913      0.998700    0.999532             NaN
# Post-Classical      NaN           NaN      0.999683         NaN        0.999927
#
#   BIGPERIOD_BIRTH - Edge Pairs Summary:
#   ----------------------------------------------------------------------------
#     Ancient         → Ancient          |  AUC: 0.9995  |  Edges: 2,437
#     Contemporary    → Contemporary     |  AUC: 0.9998  |  Edges: 89,557
#     Contemporary    → Early Modern     |  AUC: 0.9984  |  Edges: 788
#     Contemporary    → Mid Modern       |  AUC: 0.9990  |  Edges: 6,488
#     Early Modern    → Early Modern     |  AUC: 0.9999  |  Edges: 2,546
#     Early Modern    → Mid Modern       |  AUC: 0.9996  |  Edges: 771
#     Early Modern    → Post-Classical   |  AUC: 0.9999  |  Edges: 648
#     Mid Modern      → Contemporary     |  AUC: 0.9999  |  Edges: 3,141
#     Mid Modern      → Early Modern     |  AUC: 0.9987  |  Edges: 1,238
#     Mid Modern      → Mid Modern       |  AUC: 0.9995  |  Edges: 11,244
#     Post-Classical  → Early Modern     |  AUC: 0.9997  |  Edges: 549
#     Post-Classical  → Post-Classical   |  AUC: 0.9999  |  Edges: 3,646
#
#   UN_SUBREGION - AUC Matrix:
#   ----------------------------------------------------------------------------
#              Non-Western   Western
# Non-Western     0.999971  0.999572
# Western         0.999872  0.999705
#
#   UN_SUBREGION - Edge Pairs Summary:
#   ----------------------------------------------------------------------------
#     Non-Western     → Non-Western      |  AUC: 1.0000  |  Edges: 13,733
#     Non-Western     → Western          |  AUC: 0.9996  |  Edges: 9,346
#     Western         → Non-Western      |  AUC: 0.9999  |  Edges: 5,877
#     Western         → Western          |  AUC: 0.9997  |  Edges: 97,788
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  Language: ALL
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#   GENDER - AUC Matrix:
#   ----------------------------------------------------------------------------
#           Female      Male  Other
# Female  0.999870  0.999388    NaN
# Male    0.999806  0.999366    NaN
# Other        NaN       NaN    NaN
#
#   GENDER - Edge Pairs Summary:
#   ----------------------------------------------------------------------------
#     Female          → Female           |  AUC: 0.9999  |  Edges: 104,230
#     Female          → Male             |  AUC: 0.9994  |  Edges: 179,644
#     Male            → Female           |  AUC: 0.9998  |  Edges: 106,924
#     Male            → Male             |  AUC: 0.9994  |  Edges: 888,653
#
#   BIGPERIOD_BIRTH - AUC Matrix:
#   ----------------------------------------------------------------------------
#                  Ancient  Contemporary  Early Modern  Mid Modern  Post-Classical
# Ancient         0.998606      0.998147      0.993106    0.990531        0.997767
# Contemporary    0.997284      0.999772      0.997125    0.998294        0.998885
# Early Modern    0.995659      0.999579      0.999697    0.997461        0.999379
# Mid Modern      0.994638      0.999695      0.997901    0.999098        0.997941
# Post-Classical  0.997621      0.999105      0.998435    0.996193        0.999893
#
#   BIGPERIOD_BIRTH - Edge Pairs Summary:
#   ----------------------------------------------------------------------------
#     Ancient         → Ancient          |  AUC: 0.9986  |  Edges: 21,768
#     Ancient         → Contemporary     |  AUC: 0.9981  |  Edges: 2,050
#     Ancient         → Early Modern     |  AUC: 0.9931  |  Edges: 1,587
#     Ancient         → Mid Modern       |  AUC: 0.9905  |  Edges: 2,062
#     Ancient         → Post-Classical   |  AUC: 0.9978  |  Edges: 2,261
#     Contemporary    → Ancient          |  AUC: 0.9973  |  Edges: 2,685
#     Contemporary    → Contemporary     |  AUC: 0.9998  |  Edges: 813,634
#     Contemporary    → Early Modern     |  AUC: 0.9971  |  Edges: 9,679
#     Contemporary    → Mid Modern       |  AUC: 0.9983  |  Edges: 80,318
#     Contemporary    → Post-Classical   |  AUC: 0.9989  |  Edges: 3,119
#     Early Modern    → Ancient          |  AUC: 0.9957  |  Edges: 2,128
#     Early Modern    → Contemporary     |  AUC: 0.9996  |  Edges: 4,313
#     Early Modern    → Early Modern     |  AUC: 0.9997  |  Edges: 34,748
#     Early Modern    → Mid Modern       |  AUC: 0.9975  |  Edges: 8,504
#     Early Modern    → Post-Classical   |  AUC: 0.9994  |  Edges: 5,283
#     Mid Modern      → Ancient          |  AUC: 0.9946  |  Edges: 2,459
#     Mid Modern      → Contemporary     |  AUC: 0.9997  |  Edges: 44,551
#     Mid Modern      → Early Modern     |  AUC: 0.9979  |  Edges: 13,479
#     Mid Modern      → Mid Modern       |  AUC: 0.9991  |  Edges: 141,174
#     Mid Modern      → Post-Classical   |  AUC: 0.9979  |  Edges: 3,154
#     Post-Classical  → Ancient          |  AUC: 0.9976  |  Edges: 3,587
#     Post-Classical  → Contemporary     |  AUC: 0.9991  |  Edges: 2,929
#     Post-Classical  → Early Modern     |  AUC: 0.9984  |  Edges: 4,020
#     Post-Classical  → Mid Modern       |  AUC: 0.9962  |  Edges: 3,361
#     Post-Classical  → Post-Classical   |  AUC: 0.9999  |  Edges: 47,398
#
#   UN_SUBREGION - AUC Matrix:
#   ----------------------------------------------------------------------------
#              Non-Western   Western
# Non-Western     0.999939  0.999260
# Western         0.999744  0.999414
#
#   UN_SUBREGION - Edge Pairs Summary:
#   ----------------------------------------------------------------------------
#     Non-Western     → Non-Western      |  AUC: 0.9999  |  Edges: 71,521
#     Non-Western     → Western          |  AUC: 0.9993  |  Edges: 71,976
#     Western         → Non-Western      |  AUC: 0.9997  |  Edges: 55,128
#     Western         → Western          |  AUC: 0.9994  |  Edges: 1,077,892

# %% [markdown]
# ## Results Location

# %%
print(f"Results saved to: {output_dirs['base']}")
print(f"  - AUC matrices: {output_dirs['auc']}")
print(f"  - Retention curves data: {output_dirs['retention_data']}")
print(f"  - Cache metadata: {os.path.join(output_dirs['base'], 'cache_metadata.json')}")
# Out:
# Results saved to: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_fullmatch_corrected_pageview_q0.8_lang_res50_min500_langs5_attrs3
#   - AUC matrices: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_fullmatch_corrected_pageview_q0.8_lang_res50_min500_langs5_attrs3/auc
#   - Retention curves data: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_fullmatch_corrected_pageview_q0.8_lang_res50_min500_langs5_attrs3/retention_data
#   - Cache metadata: /home/vlr/Workspaces/WikipediaBiasProject/PyProject/data/out/plots/SpotlightWeightSource_0102_0505_fullmatch_corrected_pageview_q0.8_lang_res50_min500_langs5_attrs3/cache_metadata.json
